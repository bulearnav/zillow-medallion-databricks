# %% [markdown]
# ## 03_bronze_xml_state_pyspark
# ## Ingest State XML into Bronze using PySpark read/write.

# %%
from pyspark.sql import functions as F

XML_PATH = "/Volumes/zillow/zillow_medallion/raw-converted_format/xml/State_time_series.xml"
TARGET = "zillow.zillow_bronze.state_ts_xml_bronze"

df = (
    spark.read.format("xml")
    .option("rowTag", "row")          # CHANGE if XML uses a different tag
    .option("inferSchema", "true")
    .load(XML_PATH)
)

df = (
    df.withColumn("load_dt", F.current_timestamp())
      .withColumn("source_file", F.lit(XML_PATH))
      .withColumn("ingest_mode", F.lit("xml_pyspark"))
)

(df.write
   .format("delta")
   .mode("overwrite")
   .option("overwriteSchema", "true")
   .saveAsTable(TARGET)
)

spark.sql(f"""
COMMENT ON TABLE {TARGET}
IS 'State time series parsed from XML using spark-xml into Bronze.'
""")

display(spark.sql(f"SELECT COUNT(*) AS rows FROM {TARGET}"))
display(spark.sql(f"SELECT * FROM {TARGET} LIMIT 5"))
